# %%
import glob
import json
import os
import shutil

# %%
jpg_files = glob.glob(r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_viet\00.train\106-points_VIET\*\*.jpg')
jpg_files
# Out:
# ['C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_1015_1650262630335.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_1031_1650262928949.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_1038_1650262987489.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_1038_1650263181822.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_147_1650262822247.jpg',
# ...

# %%
jpg_files_pt =glob.glob(r"C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_viet_106pt\00.train\106-points_VIET\*\*.jpg")
jpg_files_pt
# Out:
# ['C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet_106pt\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_1015_1650262630335.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet_106pt\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_1031_1650262928949.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet_106pt\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_1038_1650262987489.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet_106pt\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_1038_1650263181822.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet_106pt\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_147_1650262822247.jpg',
# ...

# %%
file_list = []
for file in jpg_files:
    file_name = file.split('\\')[-1]
    file_list.append(file_name)
    
file_list
# Out:
# ['0--Parade_0_Parade_marchingband_1_1015_1650262630335.jpg',
#  '0--Parade_0_Parade_marchingband_1_1031_1650262928949.jpg',
#  '0--Parade_0_Parade_marchingband_1_1038_1650262987489.jpg',
#  '0--Parade_0_Parade_marchingband_1_1038_1650263181822.jpg',
#  '0--Parade_0_Parade_marchingband_1_147_1650262822247.jpg',
#  '0--Parade_0_Parade_marchingband_1_156_1650262803850.jpg',
#  '0--Parade_0_Parade_marchingband_1_223_1650262636898.jpg',
#  '0--Parade_0_Parade_marchingband_1_223_1650262839566.jpg',
#  '0--Parade_0_Parade_marchingband_1_251_1650262654413.jpg',
#  '0--Parade_0_Parade_marchingband_1_272_1650262725134.jpg',
#  '0--Parade_0_Parade_marchingband_1_285_1650262930830.jpg',
#  '0--Parade_0_Parade_marchingband_1_285_1650263178966.jpg',
#  '0--Parade_0_Parade_marchingband_1_353_1650263300653.jpg',
#  '0--Parade_0_Parade_marchingband_1_422_1650263097569.jpg',
#  '0--Parade_0_Parade_marchingband_1_437_1650262691459.jpg',
#  '0--Parade_0_Parade_marchingband_1_446_1650262870625.jpg',
# ...

# %%
len(file_list)
# Out:
# 7500

# %%
pt_file_list = []
for file in jpg_files_pt:
    file_name = file.split('\\')[-1]
    pt_file_list.append(file_name)
    
pt_file_list
# Out:
# ['0--Parade_0_Parade_marchingband_1_1015_1650262630335.jpg',
#  '0--Parade_0_Parade_marchingband_1_1031_1650262928949.jpg',
#  '0--Parade_0_Parade_marchingband_1_1038_1650262987489.jpg',
#  '0--Parade_0_Parade_marchingband_1_1038_1650263181822.jpg',
#  '0--Parade_0_Parade_marchingband_1_147_1650262822247.jpg',
#  '0--Parade_0_Parade_marchingband_1_156_1650262803850.jpg',
#  '0--Parade_0_Parade_marchingband_1_223_1650262636898.jpg',
#  '0--Parade_0_Parade_marchingband_1_223_1650262839566.jpg',
#  '0--Parade_0_Parade_marchingband_1_251_1650262654413.jpg',
#  '0--Parade_0_Parade_marchingband_1_272_1650262725134.jpg',
#  '0--Parade_0_Parade_marchingband_1_285_1650262930830.jpg',
#  '0--Parade_0_Parade_marchingband_1_285_1650263178966.jpg',
#  '0--Parade_0_Parade_marchingband_1_353_1650263300653.jpg',
#  '0--Parade_0_Parade_marchingband_1_422_1650263097569.jpg',
#  '0--Parade_0_Parade_marchingband_1_446_1650262870625.jpg',
#  '0--Parade_0_Parade_marchingband_1_473_1650263051123.jpg',
# ...

# %%
len(pt_file_list)
# Out:
# 7073

# %%
list_3 = [x for x in file_list if x not in pt_file_list]

# %%
list_3
# Out:
# ['0--Parade_0_Parade_marchingband_1_437_1650262691459.jpg',
#  '0--Parade_0_Parade_marchingband_1_753_1650262629408.jpg',
#  '0--Parade_0_Parade_marchingband_1_753_1650262730930.jpg',
#  '0--Parade_0_Parade_marchingband_1_847_1650262848028.jpg',
#  '0--Parade_0_Parade_marchingband_1_930_1650263278254.jpg',
#  '0--Parade_0_Parade_Parade_0_327_1650262769253.jpg',
#  '0--Parade_0_Parade_Parade_0_519_1650263196738.jpg',
#  '0--Parade_0_Parade_Parade_0_678_1650262645889.jpg',
#  '0--Parade_0_Parade_Parade_0_803_1650262792834.jpg',
#  '0--Parade_0_Parade_Parade_0_913_1650262753024.jpg',
#  '1--Handshaking_1_Handshaking_Handshaking_1_417_1650262994898.jpg',
#  '1--Handshaking_1_Handshaking_Handshaking_1_61_1650262859414.jpg',
#  '10--People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_524_1650263295922.jpg',
# ...

# %%
len(list_3)
# Out:
# 427

# %%
for pt_file in pt_file_list:
    pt_file_name = pt_file.split('\\')[-1]
    
for pt_file in pt_file_list:
    file_name = file.split('\\')[-1]
        
    if file_name not in pt_file_name:
        print(file_name)
# Out:
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# 0--Parade_0_Parade_marchingband_1_847_1650262775556.jpg
# ...

# %%
save_path = r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_none'
ori_path = r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_viet_106pt\00.train\106-points_VIET'
for file in jpg_files:
    file_name = file.split('\\')[-1]
    
    
    if file_name in list_3:
        tmp = file.split('\\')
        save_root_dir = os.path.join(save_path,tmp[6],tmp[7].tmp[8])
        os.makedirs(save_root_dir)
        ori_root = os.path.join(ori_path,tmp[8],file_name)
        
        save_root_2 = os.path.join(save_root_dir,file_name)
        shutil.copy2(ori_root,save_root_dir)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23604/4135348589.py in <module>
#       7     if file_name in list_3:
#       8         tmp = file.split('\\')
# ----> 9         save_root_dir = os.path.join(save_path,tmp[6],tmp[7].tmp[8])
#      10         os.makedirs(save_root_dir)
#      11         ori_root = os.path.join(ori_path,tmp[8],file_name)
#
# AttributeError: 'str' object has no attribute 'tmp'

# %%
save_path = r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_none'
ori_path = r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_viet\00.train\106-points_VIET'
for file in jpg_files:
    file_name = file.split('\\')[-1]
    
    
    if file_name in list_3:
        tmp = file.split('\\')
        save_root_dir = os.path.join(save_path,tmp[6],tmp[7],tmp[8])
        os.makedirs(save_root_dir)
        ori_root = os.path.join(ori_path,tmp[8],file_name)
        
        save_root_2 = os.path.join(save_root_dir,file_name)
        shutil.copy2(ori_root,save_root_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23604/364293412.py in <module>
#       8         tmp = file.split('\\')
#       9         save_root_dir = os.path.join(save_path,tmp[6],tmp[7],tmp[8])
# ---> 10         os.makedirs(save_root_dir)
#      11         ori_root = os.path.join(ori_path,tmp[8],file_name)
#      12
#
# ~\anaconda3\lib\os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_none\\00.train\\106-points_VIET\\0--Parade'

# %%
jpg_files[0]
# Out:
# 'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\00.train\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_1015_1650262630335.jpg'

# %%
save_path = r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_none'
ori_path = r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_viet\00.train\106-points_VIET'
for file in jpg_files:
    file_name = file.split('\\')[-1]
    
    
    if file_name in list_3:
        tmp = file.split('\\')
        save_root_dir = os.path.join(save_path,tmp[6],tmp[7],tmp[8])
        if not os.path.exists(save_root_dir):
            os.makedirs(save_root_dir)
            

    #파일 경로가 존재하면 그대로 복사
        else:
            clipNameDirPath = os.path.join(save_root_dir)
            
  
        oriImagePath = os.path.join(ori_path,tmp[8], file_name)
        newImagePath = os.path.join(save_root_dir,file_name)
        shutil.copy2(oriImagePath, newImagePath)

# %%
files = glob.glob(r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_none\00.train\106-points_VIET\*\*')
len(files)
# Out:
# 427

# %%
test_jpgs = glob.glob(r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_viet\01.test\*\*\*.jpg')
len(test_jpgs)
# Out:
# 2500

# %%
test_pt_jpgs = glob.glob(r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_viet_106pt\01.test\*\*\*.jpg')
len(test_pt_jpgs)
# Out:
# 2232

# %%
test_jpg_file = []
for test_jpg in test_jpgs:
    test_jpg_name = test_jpg.split("\\")[-1]
    test_jpg_file.append(test_jpg_name)

# %%
len(test_jpg_file)
# Out:
# 2500

# %%
test_pt_file = []
for test_pt_jpg in test_pt_jpgs:
    test_pt_name = test_pt_jpg.split("\\")[-1]
    test_pt_file.append(test_pt_name)

# %%
test_pt_file
# Out:
# ['0--Parade_0_Parade_marchingband_1_116_1650262375347.jpg',
#  '0--Parade_0_Parade_marchingband_1_285_1650262377638.jpg',
#  '0--Parade_0_Parade_marchingband_1_419_1650262433906.jpg',
#  '0--Parade_0_Parade_marchingband_1_446_1650262363247.jpg',
#  '0--Parade_0_Parade_marchingband_1_547_1650262464778.jpg',
#  '0--Parade_0_Parade_marchingband_1_887_1650262363439.jpg',
#  '0--Parade_0_Parade_marchingband_1_895_1650262387246.jpg',
#  '0--Parade_0_Parade_marchingband_1_895_1650262451820.jpg',
#  '0--Parade_0_Parade_marchingband_1_897_1650262376044.jpg',
#  '0--Parade_0_Parade_marchingband_1_897_1650262387724.jpg',
#  '0--Parade_0_Parade_marchingband_1_928_1650262374571.jpg',
#  '0--Parade_0_Parade_marchingband_1_939_1650262445970.jpg',
#  '0--Parade_0_Parade_marchingband_1_941_1650262449822.jpg',
#  '0--Parade_0_Parade_Parade_0_1019_1650262372756.jpg',
#  '0--Parade_0_Parade_Parade_0_1019_1650262466852.jpg',
#  '0--Parade_0_Parade_Parade_0_109_1650262451082.jpg',
# ...

# %%
len(test_pt_file)
# Out:
# 2232

# %%
test_list = [x for x in test_jpg_file if x not in test_pt_file]

# %%
test_list
# Out:
# ['0--Parade_0_Parade_marchingband_1_156_1650262393014.jpg',
#  '0--Parade_0_Parade_marchingband_1_437_1650262390047.jpg',
#  '0--Parade_0_Parade_marchingband_1_702_1650262369469.jpg',
#  '10--People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_341_1650262458735.jpg',
#  '10--People_Marching_10_People_Marching_People_Marching_2_164_1650262390618.jpg',
#  '10--People_Marching_10_People_Marching_People_Marching_2_256_1650262387315.jpg',
#  '10--People_Marching_10_People_Marching_People_Marching_2_331_1650262375494.jpg',
#  '10--People_Marching_10_People_Marching_People_Marching_2_331_1650262383091.jpg',
#  '10--People_Marching_10_People_Marching_People_Marching_2_832_1650262368235.jpg',
#  '11--Meeting_11_Meeting_Meeting_11_Meeting_Meeting_11_317_1650262374539.jpg',
#  '11--Meeting_11_Meeting_Meeting_11_Meeting_Meeting_11_317_1650262384801.jpg',
#  '11--Meeting_11_Meeting_Meeting_11_Meeting_Meeting_11_36_1650262416553.jpg',
# ...

# %%
len(test_list)
# Out:
# 268

# %%
save_path = r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_none'
ori_path = r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_viet\01.test\106-points_VIET'
for file in test_jpgs:
    file_name = file.split('\\')[-1]
    
    
    if file_name in test_list:
        tmp = file.split('\\')
        save_root_dir = os.path.join(save_path,tmp[6],tmp[7],tmp[8])
        if not os.path.exists(save_root_dir):
            os.makedirs(save_root_dir)
            

    #파일 경로가 존재하면 그대로 복사
        else:
            clipNameDirPath = os.path.join(save_root_dir)
            
  
        oriImagePath = os.path.join(ori_path,tmp[8], file_name)
        newImagePath = os.path.join(save_root_dir,file_name)
        shutil.copy2(oriImagePath, newImagePath)

# %%
test_jpgs
# Out:
# ['C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\01.test\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_116_1650262375347.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\01.test\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_156_1650262393014.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\01.test\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_285_1650262377638.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\01.test\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_419_1650262433906.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\01.test\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_437_1650262390047.jpg',
#  'C:\\Users\\alchera\\Desktop\\Naver_landmark\\02.landmark_106_viet\\01.test\\106-points_VIET\\0--Parade\\0--Parade_0_Parade_marchingband_1_446_1650262363247.jpg',
# ...

# %%
test_none = glob.glob(r'C:\Users\alchera\Desktop\Naver_landmark\02.landmark_106_none\01.test\106-points_VIET\*\*')
len(test_none)
# Out:
# 268
