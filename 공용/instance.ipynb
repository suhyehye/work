# %%
import os,glob
from os.path import join,basename,dirname
import sys,json
import numpy as np
from natsort import natsort
import pandas as pd

# %%
dir_path =r'C:\Users\alchera\Downloads\DL-E&C_1대상_1_01_0001'
df = pd.DataFrame({'csv':[], 'instance num': [],'point num':[],'avg':[]})

for (root, directories, files) in os.walk(dir_path):
    for file in files:
        if '.json' in file:
            file_path = os.path.join(root, file)
            file_name = file_path.split('\\')[-1]

            label_list = []
            point_list = []
            with open(file_path, "r",encoding='UTF-8') as f:
                data = json.load(f)
                shapes = data['shapes']
                for i in shapes:
                    label = i['label']

                    label_list.append(label)

                my_list = []

                for j in shapes:
                    
                    points = j['points']
                    my_list.append(points)
                point_list.append( my_list)
                point_list = sum(point_list,[])
                point_list = sum(point_list,[])

                instance_count = len(label_list)
                point_count = len(point_list)
                avg = round(point_count/instance_count,1)

                

                data_to_insert = {'csv':file_name, 'instance num': instance_count,'point num':point_count,'avg':avg}
                df = df.append(data_to_insert, ignore_index=True)
# Out:
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_21204\3301811551.py:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)

# %%
df.to_csv(r'C:\Users\alchera\Desktop\skt_ex\dl\aa.csv')

# %%
df
# Out:
#                                       csv  instance num  point num    avg
# 0   0ad74a37391c4542abcee318157859b1.json           5.0      251.0   50.2
# 1   0af69f45b92544ada3a79817a746ed0d.json           1.0      132.0  132.0
# 2   0b94ac27dfa74efba776e9f32cfdb2df.json           2.0      666.0  333.0
# 3   0bd11a92d9e940068583424a715905c4.json           3.0      329.0  109.7
# 4   0c998952e60641f0bf3b4e66c1530a56.json           3.0      406.0  135.3
# 5   0da2d7c500074f9c9373b36937755995.json           2.0       59.0   29.5
# 6   0db39e853f244208995628433c5db74e.json           1.0       77.0   77.0
# 7   0deee99a295648579db49e3b96c18fcd.json           1.0       23.0   23.0
# 8   0e2a044b6d43428dad4ed47b9435a15d.json           3.0      427.0  142.3
# 9   0f191a31e2d24c239e5a4d89547b79c3.json           2.0      123.0   61.5
# 10  0f2019f92379401cb38988895ebd49bf.json           4.0      101.0   25.2
# 11  0f45e8c3895549ad948978b215e10089.json           1.0       73.0   73.0
# 12  0f71f5c77b5741cc971c3d0ec4a76529.json           1.0       47.0   47.0
# 13  1a411257b59e4955a277d845f65f3725.json           1.0       34.0   34.0
# 14  1ac078ab60984ef081eeaa64c25cec7c.json           6.0      307.0   51.2
# 15  1b313b712cd045219c3a95d6f1bb7ebe.json           3.0      186.0   62.0
# 16  1b35ea07cdc24234a36d8690a006cc75.json           4.0      530.0  132.5
# 17  1b98a46c50114a61a2b363f73659a2f0.json           3.0      136.0   45.3
