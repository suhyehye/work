# %%
import pandas as pd
import numpy as np
import json
import os
import glob
import shutil

# %%
df = pd.read_csv(r'C:\Users\alchera\Desktop\Naver_landmark\csv\list_98pt_rect_attr_train_300.csv',header=None)
print(len(df))
# Out:
# 619

# %%
json_files = glob.glob(r'C:\Users\alchera\Desktop\Naver_landmark\02.Merge_folder_json\train\38-points\*.json')
print(len(json_files))
# Out:
# 7073

# %%
my_list = []
for json_file in json_files:
    json_file_name = json_file.split('\\')[-1]
    

    
    for i in df.index:
        df_name = df[0][i].split('/')[-1][:-4]
        
        
        if df_name in json_file_name:
            print(json_file_name)
            my_list.append(json_file_name)
            shutil.copy2(json_file,r'C:\Users\alchera\Desktop\Naver_landmark\csv\300\train\38-points')
# Out:
# 0--Parade_0_Parade_marchingband_1_1031_1650262928949.alchera.json
# 0--Parade_0_Parade_marchingband_1_639_1650262643740.alchera.json
# 0--Parade_0_Parade_Parade_0_705_1650262708863.alchera.json
# 0--Parade_0_Parade_Parade_0_705_1650263099247.alchera.json
# 0--Parade_0_Parade_Parade_0_705_1650263136050.alchera.json
# 0--Parade_0_Parade_Parade_0_763_1650262677436.alchera.json
# 0--Parade_0_Parade_Parade_0_773_1650262982075.alchera.json
# 1--Handshaking_1_Handshaking_Handshaking_1_333_1650263283425.alchera.json
# 1--Handshaking_1_Handshaking_Handshaking_1_457_1650263029022.alchera.json
# 1--Handshaking_1_Handshaking_Handshaking_1_561_1650263067002.alchera.json
# 1--Handshaking_1_Handshaking_Handshaking_1_567_1650263088990.alchera.json
# 1--Handshaking_1_Handshaking_Handshaking_1_722_1650262789937.alchera.json
# 1--Handshaking_1_Handshaking_Handshaking_1_762_1650262830378.alchera.json
# 1--Handshaking_1_Handshaking_Handshaking_1_762_1650263234199.alchera.json
# ...

# %%
my_list.append(json_file_name)
shutil.copy2(json_file,r'C:\Users\alchera\Desktop\Naver_landmark\csv\200\train\38-points')

# %%
print(len(my_list))
# Out:
# 2872

# %%
df_200 = pd.read_csv(r'C:\Users\alchera\Desktop\Naver_landmark\csv\list_98pt_rect_attr_train_200.csv',header=None)
print(len(df_200))
# Out:
# 1322

# %%
df_200y = pd.read_csv(r'C:\Users\alchera\Desktop\Naver_landmark\csv\list_98pt_rect_attr_train_200_y.csv',header=None)
print(len(df_200y))
# Out:
# 2077

# %%
df_200y = pd.read_csv(r'C:\Users\alchera\Desktop\Naver_landmark\csv\list_98pt_rect_attr_train_300.csv',header=None)
print(len(df_200y))
# Out:
# 619
