# %%
list_file = open(r'C:\Users\alchera\Desktop\Naver_landmark\list_98pt_rect_attr_test.txt','r')
readFile = list_file.readlines()
x = float(readFile[0].split(' ')[-11])
y = float(readFile[0].split(' ')[-10])
h = float(readFile[0].split(' ')[-8]) - y
w = float(readFile[0].split(' ')[-9]) - x
print(x,y,h,w)

# %%
print(readFile)

# %%
import pandas as pd
df = pd.DataFrame({'file_name':[],'x':[],'y':[],'h':[],'w':[]})
for i in readFile:

    x = int(i.split(' ')[-11])
    y = int(i.split(' ')[-10])
    h = int(i.split(' ')[-8]) - y
    w = int(i.split(' ')[-9]) - x
    file_name = i.split(' ')[-1]

    data_to_insert = {'file_name':file_name,'x':x, 'y':y,'h':h,'w':w}
    df = df.append(data_to_insert, ignore_index=True)
   


df.to_csv(r'C:\Users\alchera\Desktop\Naver_landmark\test_list.csv')
# Out:
# C:\Users\alchera\AppData\Local\Temp\ipykernel_24828\494626275.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_24828\494626275.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_24828\494626275.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_to_insert, ignore_index=True)
# C:\Users\alchera\AppData\Local\Temp\ipykernel_24828\494626275.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
