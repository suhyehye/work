# %%
import pandas as pd
import numpy as np
import json
import os
import glob
import shutil

# %%
jpg_files = glob.glob(r'C:\Users\alchera\Desktop\lanmark_new\03.작업대상_new\test\03.200_under\106-pt\*.jpg')
print(len(jpg_files))
# Out:
# 1818

# %%
json_files = glob.glob(r'C:\Users\alchera\Desktop\lanmark_new\03.작업대상_new\test\03.200_under\106-pt\*.json')
print(len(json_files))
# Out:
# 2232

# %%
for jpg_file in jpg_files:
    jpg_name = jpg_file.split('\\')[-1][:-4]
    shutil.copy(jpg_file,r'C:\Users\alchera\Desktop\lanmark_new\106-pt_new')

    for json_file in json_files:
        json_name = json_file.split('\\')[-1][:-13]

        if json_name == jpg_name:
            print(json_name)
            shutil.copy(json_file,r'C:\Users\alchera\Desktop\lanmark_new\106-pt_new')
# Out:
# 0--Parade_0_Parade_marchingband_1_116_1650262375347
# 0--Parade_0_Parade_marchingband_1_285_1650262377638
# 0--Parade_0_Parade_marchingband_1_419_1650262433906
# 0--Parade_0_Parade_marchingband_1_446_1650262363247
# 0--Parade_0_Parade_marchingband_1_895_1650262387246
# 0--Parade_0_Parade_marchingband_1_895_1650262451820
# 0--Parade_0_Parade_marchingband_1_897_1650262376044
# 0--Parade_0_Parade_marchingband_1_897_1650262387724
# 0--Parade_0_Parade_marchingband_1_928_1650262374571
# 0--Parade_0_Parade_marchingband_1_941_1650262449822
# 0--Parade_0_Parade_Parade_0_1019_1650262372756
# 0--Parade_0_Parade_Parade_0_1019_1650262466852
# 0--Parade_0_Parade_Parade_0_109_1650262451082
# 0--Parade_0_Parade_Parade_0_194_1650262423745
# 0--Parade_0_Parade_Parade_0_254_1650262446846
# 0--Parade_0_Parade_Parade_0_271_1650262446432
# 0--Parade_0_Parade_Parade_0_29_1650262385570
# 0--Parade_0_Parade_Parade_0_327_1650262387985
# 0--Parade_0_Parade_Parade_0_336_1650262436629
# ...

# %%
jpgs = glob.glob(r'C:\Users\alchera\Desktop\lanmark_new\106-pt_new\*.jpg')
print(len(jpgs))
# Out:
# 1818
